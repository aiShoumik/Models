# %%
import pandas as pd
import pandas_datareader as pdr
import urllib.request as ur
from bs4 import BeautifulSoup as soup
import numpy as np
import pandas_datareader as pdr
import seaborn
import statsmodels
from statsmodels.tsa.stattools import coint
import matplotlib.pyplot as plt

# %%
#collecting html from yahoo world indices website
html_1=ur.urlopen('https://finance.yahoo.com/world-indices/')
html_ticker=html_1.read().decode('utf8')
html_1.close()
html_ticker
# Out:
# '<!DOCTYPE html><html id="atomic" class="NoJs desktop" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><title>Major World Indices - Yahoo Finance</title><meta name="keywords" content="major world indices, indexes, index americas europe asia pacific africa middle east composite"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="90376669494"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="See the complete list of world stock indexes with points and percentage change, volume, intraday highs and lows, 52 week range, and day charts."/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><meta name="msvalidate.01" content="A9862C0E6E1BE95BCE0BF3D0298FD58B"/><link rel="manifest" href="/manifest.json"/><link rel="dns-prefetch" href="//l.yimg.com"/><link rel="dns-prefetch" href="//s.yimg.com"/><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"/><link rel="dns-prefetch" href="//geo.query.yahoo.com"/><link rel="dns-prefetch" href="//y.analytics.yahoo.com"/><link rel="dns-prefetch" href="//b.scorecardresearch.com"/><link rel="dns-prefetch" href="//iquery.finance.yahoo.com"/><link rel="dns-prefetch" href="//fc.yahoo.com"/><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"/><link rel="dns-prefetch" href="//yrtas.btrll.com"/><link rel="dns-prefetch" href="//shim.btrll.com"/><link rel="dns-prefetch" href="//consent.cmp.oath.com"/><link rel="dns-prefetch" href="//geo.yahoo.com"/><link rel="preconnect" href="//l.yimg.com" crossorigin="anonymous"/><link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous"/><link rel="preconnect" href="//csc.beap.bc.yahoo.com"/><link rel="preconnect" href="//geo.query.yahoo.com"/><link rel="preconnect" href="//y.analytics.yahoo.com"/><link rel="preconnect" href="//b.scorecardresearch.com"/><link rel="preconnect" href="//iquery.finance.yahoo.com"/><link rel="preconnect" href="//fc.yahoo.com"/><link rel="preconnect" href="//video-api.yql.yahoo.com"/><link rel="preconnect" href="//yrtas.btrll.com"/><link rel="preconnect" href="//shim.btrll.com"/><link rel="preconnect" href="//consent.cmp.oath.com"/><link rel="preconnect" href="//geo.yahoo.com"/><link rel="preconnect" href="//ads.yahoo.com"/><link rel="preload" href="/__finStreamer-worker.js" as="worker"/><link rel="preload" href="/__rapidworker-1.2.js" as="worker"/><link rel="icon" href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" sizes="any"/><link rel="alternate icon" href="https://s.yimg.com/cv/apiv2/default/fp/20180826/icons/favicon_y19_32x32.ico" type="image/x-icon"/><link rel="canonical" href="https://finance.yahoo.com/world-indices/"/><meta property="twitter:site" content="@YahooFinance"/><meta property="fb:pages" content="90376669494"/><meta property="og:image" content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png"/><meta property="og:description" content="See the complete list of world stock indexes with points and percentage change, volume, intraday highs and lows, 52 week range, and day charts."/><meta property="og:title" content="Major World Indices - Yahoo Finance"/><meta property="twitter:description" content="See the complete list of world stock indexes with points and percentage change, volume, intraday highs and lows, 52 week range, and day charts."/><meta property="twitter:title" content="Major World Indices - Yahoo Finance"/><meta property="al:ios:app_store_id" content="328412701"/><meta property="al:ios:app_name" content="Yahoo Finance"/><meta property="al:android:url" content="intent://#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.client.android.finance;S.browser_fallback_url=https%3A%2F%2Fplay.google.com%2Fsto ...

# %%
#extracting global ticker using bs4
raw_html=soup(html_ticker)
table=raw_html.table.find_all('td')
for td in table:
    print(td.text)
# Out:
# ^GSPC
# S&P 500
# 3,227.86
# +12.23
# +0.38%
# 276.688M
#
#
#
# ^DJI
# Dow 30
# 26,513.52
# +43.63
# +0.16%
# 46.99M
#
#
#
# ^IXIC
# Nasdaq
# 10,493.84
# +130.66
# +1.26%
# 553.094M
#
#
#
# ^NYA
# NYSE COMPOSITE (DJ)
# 12,458.79
# -2.99
# -0.02%
# 0
#
#
#
# ^XAX
# NYSE AMEX COMPOSITE INDEX
# 2,078.22
# +10.67
# +0.52%
# 0
#
#
#
# ^BUK100P
# Cboe UK 100 Price Return
# 608.29
# -2.12
# -0.35%
# 0
#
#
#
# ^RUT
# Russell 2000
# 1,466.95
# -0.61
# -0.04%
# 0
#
#
#
# ^VIX
# Vix
# 26.48
# +0.64
# +2.48%
# 0
#
#
#
# ^FTSE
# FTSE 100
# 6,101.86
# -21.96
# -0.36%
# 0
#
#
#
# ^GDAXI
# DAX PERFORMANCE-INDEX
# 12,845.88
# +7.82
# +0.06%
# 0
#
#
#
# ^FCHI
# CAC 40
# 4,937.49
# -18.94
# -0.38%
# 0
#
#
#
# ^STOXX50E
# ESTX 50 PR.EUR
# 3,302.79
# -8.10
# -0.24%
# 0
#
#
#
# ^N100
# EURONEXT 100
# 983.70
# -3.25
# -0.33%
# 0
#
#
#
# ^BFX
# BEL 20
# 3,407.51
# -27.92
# -0.81%
# 0
#
#
#
# IMOEX.ME
# MOEX Russia Index
# 2,891.94
# +28.82
# +1.01%
# 0
#
#
#
# ^N225
# Nikkei 225
# 22,715.85
# -35.76
# -0.16%
# 0
#
#
#
# ^HSI
# HANG SENG INDEX
# 24,603.26
# -102.07
# -0.41%
# 0
#
#
#
# 000001.SS
# SSE Composite Index
# 3,205.23
# +8.46
# +0.26%
# 4.162B
#
#
#
# 399001.SZ
# Shenzhen Component
# 12,976.87
# +41.17
# +0.32%
# 3.823B
#
#
#
# ^STI
# STI Index
# 2,575.79
# -3.72
# -0.14%
# 0
#
#
#
# ^AXJO
# S&P/ASX 200
# 6,044.20
# +20.20
# +0.34%
# 0
#
#
#
# ^AORD
# ALL ORDINARIES
# 6,169.60
# +21.60
# +0.35%
# 0
#
#
#
# ^BSESN
# S&P BSE SENSEX
# 37,934.73
# -194.17
# -0.51%
# 0
#
#
#
# ^JKSE
# Jakarta Composite Index
# 5,116.67
# +33.67
# +0.66%
# 0
#
#
#
# ^KLSE
# FTSE Bursa Malaysia KLCI
# 1,591.48
# +1.87
# +0.12%
# 0
#
#
#
# ^NZ50
# S&P/NZX 50 INDEX GROSS
# 11,585.62
# -50.64
# -0.44%
# 0
#
#
#
# ^KS11
# KOSPI Composite Index
# 2,217.86
# +17.42
# +0.79%
# 928,624
#
#
#
# ^TWII
# TSEC weighted index
# 12,588.30
# +284.26
# +2.31%
# 0
#
#
#
# ^GSPTSE
# S&P/TSX Composite index
# 16,028.29
# +31.23
# +0.20%
# 13.718M
#
#
#
# ^BVSP
# IBOVESPA
# 102,893.49
# +511.91
# +0.50%
# 0
#
#
#
# ^MXX
# IPC MEXICO
# 37,288.54
# -68.92
# -0.18%
# 1.711M
#
#
#
# ^IPSA
# S&P/CLX IPSA
# 5,058.88
# 0.00
# 0.00%
# 0
#
#
#
# ^MERV
# MERVAL
# 38,390.84
# +233.89
# +0.61%
# 0
#
#
#
# ^TA125.TA
# TA-125
# 1,372.40
# -0.30
# -0.02%
# 0
#
#
#
# ^CASE30
# EGX 30 Price Return Index
# 10,575.50
# +51.00
# +0.48%
# 198.664M
#
#
#
# ^JN0U.JO
# Top 40 USD Net TRI Index
# 3,366.28
# +62.51
# +1.89%
# 0

# %%
#extracting global ticker using pandas
pd_html=pd.read_html('https://finance.yahoo.com/world-indices/',header=0)
for tab in pd_html:
    ticker=pd.DataFrame(tab)
    continue

# %%
tickers=np.array(list(ticker['Symbol']))
tickers
# Out:
# array(['^GSPC', '^DJI', '^IXIC', '^NYA', '^XAX', '^BUK100P', '^RUT',
#        '^VIX', '^FTSE', '^GDAXI', '^FCHI', '^STOXX50E', '^N100', '^BFX',
#        'IMOEX.ME', '^N225', '^HSI', '000001.SS', '399001.SZ', '^STI',
#        '^AXJO', '^AORD', '^BSESN', '^JKSE', '^KLSE', '^NZ50', '^KS11',
#        '^TWII', '^GSPTSE', '^BVSP', '^MXX', '^IPSA', '^MERV', '^TA125.TA',
#        '^CASE30', '^JN0U.JO'], dtype='<U9')

# %%
#missing tickers data in yahoo finance ^FTSE','^STI',^KLSE
unavailable=['^KLSE','^FTSE','^STI']
#removing missing tickers
for item in unavailable:
    tickers=tickers[tickers!=item]
tickers
# Out:
# array(['^GSPC', '^DJI', '^IXIC', '^NYA', '^XAX', '^BUK100P', '^RUT',
#        '^VIX', '^GDAXI', '^FCHI', '^STOXX50E', '^N100', '^BFX',
#        'IMOEX.ME', '^N225', '^HSI', '000001.SS', '399001.SZ', '^AXJO',
#        '^AORD', '^BSESN', '^JKSE', '^NZ50', '^KS11', '^TWII', '^GSPTSE',
#        '^BVSP', '^MXX', '^IPSA', '^MERV', '^TA125.TA', '^CASE30',
#        '^JN0U.JO'], dtype='<U9')

# %%
#extracting data
start="2002-01-01"
end = "2020-06-30"
raw_data={}
for code in tickers:
    try:
        raw_data['{}'.format(code)]=pdr.get_data_yahoo(code,start,end)
    except KeyError:
        pass
'''
for i in range(0,len(tickers)):
try:
x=data.DataReader(tickers[i],'yahoo',start_date,end_date)
x.to_excel(tickers[i]+'.xlsx')
except KeyError:
pass
'''
# Out:
# "\nfor i in range(0,len(tickers)):\ntry:\nx=data.DataReader(tickers[i],'yahoo',start_date,end_date)\nx.to_excel(tickers[i]+'.xlsx')\nexcept KeyError:\npass\n"

# %%
for i in raw_data.keys():
    raw_data[i].to_csv('C:\\Users\\PC\\Desktop\\Thesis\\database\\thesis_data\\{file}.csv'.format(file=i))

# %%
raw_data.keys()
# Out:
# dict_keys(['^GSPC', '^DJI', '^IXIC', '^NYA', '^XAX', '^BUK100P', '^RUT', '^VIX', '^GDAXI', '^FCHI', '^STOXX50E', '^N100', '^BFX', 'IMOEX.ME', '^N225', '^HSI', '000001.SS', '399001.SZ', '^AXJO', '^AORD', '^BSESN', '^JKSE', '^NZ50', '^KS11', '^TWII', '^GSPTSE', '^BVSP', '^MXX', '^IPSA', '^MERV', '^TA125.TA', '^JN0U.JO'])

# %%
raw_data['^GSPC']['Adj Close']
# Out:
# Date
# 2002-01-02    1154.670044
# 2002-01-03    1165.270020
# 2002-01-04    1172.510010
# 2002-01-07    1164.890015
# 2002-01-08    1160.709961
#                  ...
# 2020-06-24    3050.330078
# 2020-06-25    3083.760010
# 2020-06-26    3009.050049
# 2020-06-29    3053.239990
# 2020-06-30    3100.290039
# Name: Adj Close, Length: 4656, dtype: float64

# %%
#forming dataframe with all the adj closing price
master_data=pd.DataFrame(index=raw_data['^GSPC'].index)

# %%
for column in raw_data.keys():
    master_data[column]=raw_data[column]['Adj Close']

# %%
#save as csv master data
master_data.to_csv('C:\\Users\\PC\\Desktop\\Thesis\\database\\thesis_data\\master_data.csv')
master_data
# Out:
#                   ^GSPC          ^DJI         ^IXIC          ^NYA  \
# Date
# 2002-01-02  1154.670044  10073.400391   1979.250000   6244.209961
# 2002-01-03  1165.270020  10172.139648   2044.270020   6266.310059
# 2002-01-04  1172.510010  10259.740234   2059.379883   6307.970215
# 2002-01-07  1164.890015  10197.049805   2037.099976   6271.810059
# 2002-01-08  1160.709961  10150.549805   2055.739990   6235.430176
# ...                 ...           ...           ...           ...
# 2020-06-24  3050.330078  25445.939453   9909.169922  11726.540039
# 2020-06-25  3083.760010  25745.599609  10017.000000  11865.110352
# 2020-06-26  3009.050049  25015.550781   9757.219727  11604.429688
# 2020-06-29  3053.239990  25595.800781   9874.150391  11777.080078
# 2020-06-30  3100.290039  25812.880859  10058.769531  11893.780273
#
#                    ^XAX      ^BUK100P         ^RUT       ^VIX        ^GDAXI  \
# Date
# 2002-01-02   843.750000           NaN   487.190002  22.709999   5167.879883
# 2002-01-03   842.250000           NaN   495.510010  21.340000   5270.290039
# 2002-01-04   841.440002           NaN   499.299988  20.450001   5318.729980
# 2002-01-07   837.330017           NaN   493.179993  21.940001   5232.220215
# 2002-01-08   836.200012           NaN   497.899994  21.830000   5236.370117
# ...                 ...           ...          ...        ...           ...
# 2020-06-24  1949.699951  10371.440430  1389.739990  33.840000  12093.940430
# 2020-06-25  1956.819946  10417.110352  1413.310059  32.220001  12177.870117
# 2020-06-26  1911.760010  10440.040039  1378.780029  34.730000  12089.389648
# 2020-06-29  1952.979980  10550.559570  1421.209961  31.780001  12232.120117
# 2020-06-30  1993.150024  10457.589844  1441.369995  30.430000  12310.929688
#
#                   ^FCHI  ...         ^NZ50        ^KS11         ^TWII  \
# Date                     ...
# 2002-01-02  4580.439941  ...           NaN   724.950012   5600.028809
# 2002-01-03  4681.200195  ...           NaN   727.659973   5526.299316
# 2002-01-04  4682.790039  ...           NaN   747.719971   5638.508789
# 2002-01-07  4615.540039  ...           NaN   751.479980   5834.868164
# 2002-01-08  4568.089844  ...           NaN   734.760010   5810.058594
# ...                 ...  ...           ...          ...           ...
# 2020-06-24  4871.359863  ...  11124.360352  2161.510010  11660.669922
# 2020-06-25  4918.580078  ...  11129.230469  2112.370117           NaN
# 2020-06-26  4909.640137  ...           NaN  2134.649902           NaN
# 2020-06-29  4945.459961  ...  11422.099609  2093.479980  11542.620117
# 2020-06-30  4935.990234  ...  11350.269531  2108.330078  11621.240234
#
#                  ^GSPTSE    ^BVSP          ^MXX        ^IPSA         ^MERV  \
# Date
# 2002-01-02   7646.799805  13872.0   6410.049805  1185.750000    323.690002
# 2002-01-03   7774.200195  14265.0   6603.750000  1195.930054    340.600006
# 2002-01-04   7833.200195  14332.0   6612.080078  1203.380005    343.220001
# 2002-01-07   7870.299805  14379.0   6565.439941  1188.949951           NaN
# 2002-01-08   7782.000000  14168.0   6641.140137  1168.010010           NaN
# ...                  ...      ...           ...          ...           ...
# 2020-06-24  15294.400391  94377.0  37908.378906          NaN  40435.339844
# 2020-06-25  15446.099609  95983.0  37734.519531          NaN  41996.648438
# 2020-06-26  15189.000000  93834.0  37431.949219          NaN  40589.890625
# 2020-06-29  15389.700195  95735.0  37769.191406          NaN  40308.109375
# 2020-06-30  15515.200195  95056.0  37716.429688          NaN  38686.691406
#
#               ^TA125.TA     ^JN0U.JO
# Date
# 2002-01-02   464.250000          NaN
# 2002-01-03   466.299988          NaN
# 2002-01-04          NaN          NaN
# 2002-01-07   468.920013          NaN
# 2002-01-08   460.779999          NaN
# ...                 ...          ...
# 2020-06-24  1348.689941  3116.879883
# 2020-06-25  1339.949951  3095.979980
# 2020-06-26          NaN  3067.770020
# 2020-06-29  1311.540039  3101.570068
# 2020-06-30  1324.130005  3104.169922
#
# [4656 rows x 32 columns]

# %%
#missing values
master_data.isnull().sum()
# Out:
# ^GSPC           0
# ^DJI            0
# ^IXIC           0
# ^NYA            0
# ^XAX            0
# ^BUK100P     2241
# ^RUT            0
# ^VIX            0
# ^GDAXI         82
# ^FCHI          48
# ^STOXX50E    1448
# ^N100          48
# ^BFX           49
# IMOEX.ME     2901
# ^N225         279
# ^HSI          213
# 000001.SS     244
# 399001.SZ     245
# ^AXJO         535
# ^AORD         534
# ^BSESN        229
# ^JKSE         267
# ^NZ50        1262
# ^KS11         236
# ^TWII         256
# ^GSPTSE        79
# ^BVSP         197
# ^MXX          137
# ^IPSA         424
# ^MERV         254
# ^TA125.TA    1115
# ^JN0U.JO     3983
# dtype: int64

# %%
#remove all indices with greater than 600 missing values
remove=['^BUK100P','^STOXX50E','IMOEX.ME','^NZ50','^TA125.TA','^JN0U.JO']
master_data=master_data.drop(columns=remove)

# %%
#forward filling the missing value
master_data=master_data.fillna(method='ffill')
master_data=master_data.dropna()
master_data.isnull().sum()
# Out:
# ^GSPC        0
# ^DJI         0
# ^IXIC        0
# ^NYA         0
# ^XAX         0
# ^RUT         0
# ^VIX         0
# ^GDAXI       0
# ^FCHI        0
# ^N100        0
# ^BFX         0
# ^N225        0
# ^HSI         0
# 000001.SS    0
# 399001.SZ    0
# ^AXJO        0
# ^AORD        0
# ^BSESN       0
# ^JKSE        0
# ^KS11        0
# ^TWII        0
# ^GSPTSE      0
# ^BVSP        0
# ^MXX         0
# ^IPSA        0
# ^MERV        0
# dtype: int64

# %%
#coint pair search
def find_cointegrated_pairs(data):
    n = data.shape[1]
    score_matrix = np.zeros((n, n))
    pvalue_matrix = np.ones((n, n))
    keys = data.keys()
    pairs = []
    for i in range(n):
        for j in range(i+1, n):
            S1 = data[keys[i]]
            S2 = data[keys[j]]
            result = coint(S1, S2)
            score = result[0]
            pvalue = result[1]
            score_matrix[i, j] = score
            pvalue_matrix[i, j] = pvalue
            if pvalue < 0.05:
                pairs.append((keys[i], keys[j]))
    return score_matrix, pvalue_matrix, pairs

# %%
cores, pvalues, pairs = find_cointegrated_pairs(master_data)
m = [0,0.2,0.4,0.6,0.8,1]
seaborn.heatmap(pvalues, xticklabels=master_data.columns, 
                yticklabels=master_data.columns, cmap='RdYlGn_r' 
                , mask = (pvalues >= 0.98)
                )
plt.show()
print(pairs)
# Out:
# [('^IXIC', '^MERV'), ('^VIX', '^GDAXI'), ('^VIX', '^FCHI'), ('^VIX', '^N100'), ('^VIX', '^BFX'), ('^VIX', '^N225'), ('^VIX', '^HSI'), ('^VIX', '000001.SS'), ('^VIX', '399001.SZ'), ('^VIX', '^AXJO'), ('^VIX', '^AORD'), ('^VIX', '^BSESN'), ('^VIX', '^JKSE'), ('^VIX', '^KS11'), ('^VIX', '^TWII'), ('^VIX', '^GSPTSE'), ('^VIX', '^BVSP'), ('^VIX', '^MXX'), ('^VIX', '^IPSA'), ('^VIX', '^MERV'), ('^GDAXI', '^BSESN'), ('^GDAXI', '^TWII'), ('^FCHI', '^BFX'), ('^FCHI', '^AXJO'), ('^N100', '^N225'), ('^N100', '^AXJO'), ('^N100', '^AORD'), ('^HSI', '^KS11'), ('^HSI', '^GSPTSE'), ('^BSESN', '^TWII'), ('^KS11', '^MXX'), ('^KS11', '^IPSA'), ('^TWII', '^GSPTSE')]

# %%
#analyzing to find the right pair
coint_pairs=[('^GDAXI', '^BSESN'), ('^GDAXI', '^TWII'), ('^FCHI', '^BFX'), ('^FCHI', '^AXJO'), ('^N100', '^N225'), ('^N100', '^AXJO'), ('^N100', '^AORD'), ('^HSI', '^KS11'), ('^HSI', '^GSPTSE'), ('^BSESN', '^TWII'), ('^KS11', '^MXX'), ('^KS11', '^IPSA'), ('^TWII', '^GSPTSE')]
for pairs in coint_pairs:
    S1 = master_data[pairs[0]]
    S2 = master_data[pairs[1]]
    score, pvalue, _ = coint(S1, S2)
    print('P-value of {pair} and {pair2}: {value}'.format(pair=pairs[0],pair2=pairs[1],value=pvalue))
    ratios = S1 / S2
    ratios.plot(figsize=(15,7))
    plt.axhline(ratios.mean())
    plt.legend(['Price Ratio'])
    plt.title('{pair} and {pair2}'.format(pair=pairs[0],pair2=pairs[1]))
    plt.show()
# Out:
# P-value of ^GDAXI and ^BSESN: 0.027947142390145674
# P-value of ^GDAXI and ^TWII: 0.033404861972616114
# P-value of ^FCHI and ^BFX: 0.005339687398320635
# P-value of ^FCHI and ^AXJO: 0.0381735890924039
# P-value of ^N100 and ^N225: 0.02468367256242098
# P-value of ^N100 and ^AXJO: 0.025460469623918
# P-value of ^N100 and ^AORD: 0.027911295977987013
# P-value of ^HSI and ^KS11: 0.027452121532171782
# P-value of ^HSI and ^GSPTSE: 0.006458556382781373
# P-value of ^BSESN and ^TWII: 0.025230462185143392
# P-value of ^KS11 and ^MXX: 0.004015563350677852
# P-value of ^KS11 and ^IPSA: 0.015360270748289367
# P-value of ^TWII and ^GSPTSE: 0.026995652336526513

# %%
big_diff=[('^GDAXI', '^BSESN'),('^BSESN', '^TWII'),('^KS11', '^MXX')]
coint_pairs=[('^GDAXI', '^TWII'), ('^FCHI', '^BFX'), ('^FCHI', '^AXJO'), ('^N100', '^N225'), ('^N100', '^AXJO'), ('^N100', '^AORD'), ('^HSI', '^KS11'), ('^HSI', '^GSPTSE'), ('^KS11', '^IPSA'), ('^TWII', '^GSPTSE')]

# %%
def zscore(series):
    return (series - series.mean()) / np.std(series)

# %%
for pairs in coint_pairs:
    S1 = master_data[pairs[0]]
    S2 = master_data[pairs[1]]
    score, pvalue, _ = coint(S1, S2)
    print('P-value of {pair} and {pair2}: {value}'.format(pair=pairs[0],pair2=pairs[1],value=pvalue))
    ratios = S1 / S2
    zscore(ratios).plot(figsize=(15,7))
    plt.axhline(zscore(ratios).mean(), color='black')
    plt.axhline(1.0, color='red', linestyle='--')
    plt.axhline(-1.0, color='green', linestyle='--')
    plt.legend(['Ratio z-score', 'Mean', '+1', '-1'])
    plt.title('{pair} and {pair2}'.format(pair=pairs[0],pair2=pairs[1]))
    plt.show()
# Out:
# P-value of ^GDAXI and ^TWII: 0.033404861972616114
# P-value of ^FCHI and ^BFX: 0.005339687398320635
# P-value of ^FCHI and ^AXJO: 0.0381735890924039
# P-value of ^N100 and ^N225: 0.02468367256242098
# P-value of ^N100 and ^AXJO: 0.025460469623918
# P-value of ^N100 and ^AORD: 0.027911295977987013
# P-value of ^HSI and ^KS11: 0.027452121532171782
# P-value of ^HSI and ^GSPTSE: 0.006458556382781373
# P-value of ^KS11 and ^IPSA: 0.015360270748289367
# P-value of ^TWII and ^GSPTSE: 0.026995652336526513

# %%
master_data.iloc[:,:-1].corr()['^HSI'].sort_values(ascending=False)
# Out:
# ^HSI         1.000000
# ^KS11        0.946234
# ^GSPTSE      0.944341
# ^TWII        0.934701
# ^XAX         0.910087
# ^BSESN       0.906401
# ^IPSA        0.902795
# ^MXX         0.899672
# ^AORD        0.899073
# ^BVSP        0.891328
# ^AXJO        0.889444
# ^JKSE        0.882095
# ^NYA         0.880079
# ^GDAXI       0.879355
# ^RUT         0.837517
# ^DJI         0.791867
# ^GSPC        0.780797
# ^IXIC        0.761595
# 399001.SZ    0.761050
# ^N100        0.751230
# 000001.SS    0.744771
# ^N225        0.709025
# ^FCHI        0.645056
# ^BFX         0.604869
# ^VIX        -0.290246
# Name: ^HSI, dtype: float64

# %%
#^HSI and ^GSPTSE: 0.006458556382781373
ratios = master_data['^HSI'] / master_data['^GSPTSE']
print(len(ratios))
train = ratios[:2791]
test = ratios[2791:]
# Out:
# 4654

# %%
ratios_mavg5 = train.rolling(window=5,
                               center=False).mean()

ratios_mavg60 = train.rolling(window=60,
                               center=False).mean()

std_60 = train.rolling(window=60,
                        center=False).std()

zscore_60_5 = (ratios_mavg5 - ratios_mavg60)/std_60
plt.figure(figsize=(15,7))
plt.plot(train.index, train.values)
plt.plot(ratios_mavg5.index, ratios_mavg5.values)
plt.plot(ratios_mavg60.index, ratios_mavg60.values)

plt.legend(['Ratio','5d Ratio MA', '60d Ratio MA'])

plt.ylabel('Ratio')
plt.show()

# %%
# Take a rolling 60 day standard deviation
std_60 = train.rolling(window=60,center=False).std()
std_60.name = 'std 60d'

# Compute the z score for each day
zscore_60_5 = (ratios_mavg5 - ratios_mavg60)/std_60
zscore_60_5.name = 'z-score'

plt.figure(figsize=(15,7))
zscore_60_5.plot()
plt.axhline(0, color='black')
plt.axhline(1.0, color='red', linestyle='--')
plt.axhline(-1.0, color='green', linestyle='--')
plt.legend(['Rolling Ratio z-Score', 'Mean', '+1', '-1'])
plt.show()

# %%
# Plot the ratios and buy and sell signals from z score
plt.figure(figsize=(15,7))

train[60:].plot()
buy = train.copy()
sell = train.copy()
buy[zscore_60_5>-1] = 0
sell[zscore_60_5<1] = 0
buy[60:].plot(color='g', linestyle='None', marker='^')
sell[60:].plot(color='r', linestyle='None', marker='^')
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,ratios.min(),ratios.max()))
plt.legend(['Ratio', 'Buy Signal', 'Sell Signal'])
plt.show()

# %%
# Plot the prices and buy and sell signals from z score
#^HSI and ^GSPTSE: 0.006458556382781373
plt.figure(figsize=(18,9))
S1 = master_data['^HSI'].iloc[:2791]
S2 = master_data['^GSPTSE'].iloc[:2791]

S1[60:].plot(color='b')
S2[60:].plot(color='c')
buyR = 0*S1.copy()
sellR = 0*S1.copy()

# When buying the ratio, buy S1 and sell S2
buyR[buy!=0] = S1[buy!=0]
sellR[buy!=0] = S2[buy!=0]
# When selling the ratio, sell S1 and buy S2 
buyR[sell!=0] = S2[sell!=0]
sellR[sell!=0] = S1[sell!=0]

buyR[60:].plot(color='g', linestyle='None', marker='^')
sellR[60:].plot(color='r', linestyle='None', marker='^')
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,min(S1.min(),S2.min()),max(S1.max(),S2.max())))

plt.legend(['^HSI','^GSPTSE', 'Buy Signal', 'Sell Signal'])
plt.show()

# %%
def trade(S1, S2, window1, window2):
    # If window length is 0, algorithm doesn't make sense, so exit
    if (window1 == 0) or (window2 == 0):
        return 0
    # Compute rolling mean and rolling standard deviation
    ratios = S1/S2
    ma1 = ratios.rolling(window=window1,
                               center=False).mean()
    ma2 = ratios.rolling(window=window2,
                               center=False).mean()
    std = ratios.rolling(window=window2,
                        center=False).std()
    zscore = (ma1 - ma2)/std
    # Simulate trading
    # Start with no money and no positions
    money = 0
    countS1 = 0
    countS2 = 0
    for i in range(len(ratios)):
        # Sell short if the z-score is > 1
        if zscore[i] > 1:
            money += S1[i] - S2[i] * ratios[i]
            countS1 -= 1
            countS2 += ratios[i]
        # Buy long if the z-score is < 1
        elif zscore[i] < -1:
            money -= S1[i] - S2[i] * ratios[i]
            countS1 += 1
            countS2 -= ratios[i]
        # Clear positions if the z-score between -.5 and .5
        elif abs(zscore[i]) < 0.5:
            money += countS1*S1[i] + S2[i] * countS2
            countS1 = 0
            countS2 = 0
#         print('Z-score: '+ str(zscore[i]), countS1, countS2, S1[i] , S2[i])
    return money


trade(master_data['^HSI'].iloc[:2791], master_data['^GSPTSE'].iloc[:2791], 5, 60)
# Out:
# 172883.5325900742

# %%
#test set result
trade(master_data['^HSI'].iloc[2791:], master_data['^GSPTSE'].iloc[2791:], 5, 60)
# Out:
# 6221.006175239469

# %%
# Find the window length 0-254 
# that gives the highest returns using this strategy
length_scores = [trade(master_data['^HSI'].iloc[:2791], 
                master_data['^GSPTSE'].iloc[:2791], 5, l) 
                for l in range(255)]
best_length = np.argmax(length_scores)
print ('Best window length:', best_length)
# Out:
# Best window length: 193

# %%
# Find the returns for test data
# using what we think is the best window length
length_scores2 = [trade(master_data['^HSI'].iloc[2791:], 
                master_data['^GSPTSE'].iloc[2791:],5, l) 
                  for l in range(255)]
print (best_length, 'day window:', length_scores2[best_length])

# Find the best window length based on this dataset, 
# and the returns using this window length
best_length2 = np.argmax(length_scores2)
print (best_length2, 'day window:', length_scores2[best_length2])
# Out:
# 193 day window: 382773.15387528157
# 177 day window: 714508.639555918

# %%
plt.figure(figsize=(15,7))
plt.plot(length_scores)
plt.plot(length_scores2)
plt.xlabel('Window length')
plt.ylabel('Score')
plt.legend(['Training', 'Test'])
plt.show()
