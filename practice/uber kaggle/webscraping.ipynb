# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
r=requests.get('https://en.wikipedia.org/wiki/S%26P_100')
soup=bs(r.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    S&amp;P 100 - Wikipedia
#   </title>
#   <script>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>S&amp;P 100 - Wikipedia</title>

# %%
tables=soup.find_all('table')
print(len(tables))
print()
print(tables[0].prettify())
# Out:
# 4
#
# <table class="infobox vcard" style="width:22em">
#  <caption class="fn n org">
#   S&amp;P500
#  </caption>
#  <tbody>
#   <tr>
#    <th scope="row">
#     Foundation
#    </th>
#    <td>
#     June 15, 1983
#     <span class="noprint">
#      ; 36 years ago
#     </span>
#     <span style="display:none">
#      (
#      <span class="bday dtstart published updated">
#       1983-06-15
#      </span>
#      )
#     </span>
#     <sup class="reference" id="cite_ref-S&amp;P500_1-0">
#      <a href="#cite_note-S&amp;P500-1">
#       [1]
#      </a>
#     </sup>
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
#     Operator
#    </th>
#    <td>
#     <a href="/wiki/S%26P_Dow_Jones_Indices" title="S&amp;P Dow Jones Indices">
#      S&amp;P Dow Jones Indices
#     </a>
#     <sup class="reference" id="cite_ref-S&amp;P500Details_2-0">
#      <a href="#cite_note-S&amp;P500Details-2">
#       [2]
#      </a>
#     </sup>
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
# ...

# %%
sortable_tables=soup.find_all('table',{'class':'sortable'})
print(len(sortable_tables))
print(sortable_tables[0].prettify())
# Out:
# 2
# <table class="wikitable sortable" id="constituents">
#  <tbody>
#   <tr>
#    <th>
#     Symbol
#    </th>
#    <th>
#     Name
#    </th>
#   </tr>
#   <tr>
#    <td>
#     AAPL
#    </td>
#    <td>
#     <a href="/wiki/Apple_Inc." title="Apple Inc.">
#      Apple Inc.
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     ABBV
#    </td>
#    <td>
#     <a href="/wiki/AbbVie_Inc." title="AbbVie Inc.">
#      AbbVie Inc.
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     ABT
#    </td>
#    <td>
#     <a href="/wiki/Abbott_Laboratories" title="Abbott Laboratories">
#      Abbott Laboratories
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     ACN
#    </td>
#    <td>
#     <a href="/wiki/Accenture" title="Accenture">
#      Accenture
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     ADBE
#    </td>
#    <td>
#     <a href="/wiki/Adobe_Inc." title="Adobe Inc.">
#      Adobe Inc.
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     AIG
#    </td>
#    <td>
# ...

# %%
sortable_tables[0].attrs
# Out:
# {'class': ['wikitable', 'sortable'], 'id': 'constituents'}

# %%
text=sortable_tables[0]
print(text.text)
# Out:
# Symbol
#
# Name
#
#
# AAPL
#
# Apple Inc.
#
#
# ABBV
#
# AbbVie Inc.
#
#
# ABT
#
# Abbott Laboratories
#
#
# ACN
#
# Accenture
#
#
# ADBE
#
# Adobe Inc.
#
#
# AIG
#
# American International Group
#
#
# ALL
#
# Allstate
#
#
# AMGN
#
# Amgen Inc.
#
#
# AMT
#
# American Tower
#
#
# AMZN
#
# Amazon.com
#
#
# AXP
#
# American Express
#
#
# BA
#
# Boeing Co.
#
#
# BAC
#
# Bank of America Corp
#
#
# BIIB
#
# Biogen
#
#
# BK
#
# The Bank of New York Mellon
#
#
# BKNG
#
# Booking Holdings
#
#
# BLK
#
# BlackRock Inc
#
#
# BMY
#
# Bristol-Myers Squibb
#
#
# BRK.B
#
# Berkshire Hathaway
#
#
# C
#
# Citigroup Inc
#
#
# CAT
#
# Caterpillar Inc.
#
#
# CHTR
#
# Charter Communications
#
#
# CL
#
# Colgate-Palmolive
#
#
# CMCSA
#
# Comcast Corp.
#
#
# COF
#
# Capital One Financial Corp.
#
#
# COP
#
# ConocoPhillips
#
#
# COST
#
# Costco Wholesale Corp.
#
#
# CRM
#
# salesforce.com
#
#
# CSCO
#
# Cisco Systems
#
#
# CVS
#
# CVS Health
#
#
# CVX
#
# Chevron Corporation
#
#
# DD
#
# ...

# %%
sortable_table_classes=[table.attrs['class'] for table in sortable_tables]
for class_list in sortable_table_classes:
    print(class_list)
# Out:
# ['wikitable', 'sortable']
# ['wikitable', 'sortable']

# %%
apple_text_elements=soup.find_all(text='Apple Inc.')
print(apple_text_elements)
# Out:
# ['Apple Inc.']

# %%
print(type(apple_text_elements[0]))
# Out:
# <class 'bs4.element.NavigableString'>

# %%
apple_text_elements[0].parent
# Out:
# <a href="/wiki/Apple_Inc." title="Apple Inc.">Apple Inc.</a>

# %%
apple_text_elements[0].parent.parent
# Out:
# <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple Inc.</a>
# </td>

# %%
apple_text_elements[0].find_parent('tbody')
# Out:
# <tbody><tr>
# <th>Symbol
# </th>
# <th>Name
# </th></tr>
# <tr>
# <td>AAPL
# </td>
# <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple Inc.</a>
# </td></tr>
# <tr>
# <td>ABBV
# </td>
# <td><a href="/wiki/AbbVie_Inc." title="AbbVie Inc.">AbbVie Inc.</a>
# </td></tr>
# <tr>
# <td>ABT
# </td>
# <td><a href="/wiki/Abbott_Laboratories" title="Abbott Laboratories">Abbott Laboratories</a>
# </td></tr>
# <tr>
# <td>ACN
# </td>
# <td><a href="/wiki/Accenture" title="Accenture">Accenture</a>
# </td></tr>
# <tr>
# <td>ADBE
# </td>
# <td><a href="/wiki/Adobe_Inc." title="Adobe Inc.">Adobe Inc.</a>
# </td></tr>
# <tr>
# <td>AIG
# </td>
# <td><a href="/wiki/American_International_Group" title="American International Group">American International Group</a>
# </td></tr>
# <tr>
# <td>ALL
# </td>
# <td><a href="/wiki/Allstate" title="Allstate">Allstate</a>
# </td></tr>
# <tr>
# <td>AMGN
# </td>
# <td><a href="/wiki/Amgen" title="Amgen">Amgen Inc.</a>
# </td></tr>
# <tr>
# <td>AMT
# </td>
# ...

# %%
tables.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-be0ecdefc7ff> in <module>
# ----> 1 tables.find_all('tr')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
